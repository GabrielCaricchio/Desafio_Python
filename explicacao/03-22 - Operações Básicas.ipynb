# %% [markdown]
# ### Adição

# %%
print(2 + 2)
# Out:
# 4

# %% [markdown]
# ### Subtração

# %%
print(2 - 2)
# Out:
# 0

# %% [markdown]
# ### Multiplicação

# %%
print(2 * 5)
# Out:
# 10

# %% [markdown]
# ### Divisão

# %%
num1 = 2
num2 = 5
print(num1 / num2)
# e divisão por zero?
# Out:
# 0.4

# %% [markdown]
# ### Potência

# %%
print( 2 ** 5)
# Out:
# 32

# %% [markdown]
# ### Raiz

# %%
print(9 ** (1/2))
# Out:
# 3.0

# %% [markdown]
# ### Mod - o resto da divisão

# %%
print(7 % 3) 

print(4 % 2)
# Out:
# 1
# 0

# %% [markdown]
# ### Ordem das operações

# %%
# Mesma ordem matemática (use parênteses para mudar)
